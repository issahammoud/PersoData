# %%
real_dir = 'RawData/Real/' 
fake_dir = 'RawData/Fake/'

# %%
real_list=!ls $real_dir
fake_list=!ls $fake_dir

# %%
test=l[0]
test=real_dir+test
test
# Out:
# 'RawData/Real/0_the-collier-s-hut.jpg!Large.jpg'

# %%
result=np.zeros((75,50176))

# %%
result.shape
# Out:
# (75, 50176)

# %%
np.savetxt('test2.out', result, fmt='%.6e', delimiter=' ')

# %%
f=open("label","a")
for i in range(76):
    f.write("1\n")
for i in range(76):
    f.write("0\n")
f.close()

# %%
k=0
result=np.zeros((75,50176))
for i in fake_list:
    if k<75:
        name=fake_dir+i
        realfile = Image.open(name)
        data = np.asarray(realfile, dtype="double")
        n=np.mean(data, axis=2)/255
        r=n.reshape((1,224*224))
        result[k]=r
        print(r.shape)
        k+=1
    else:
        break
# np.savetxt('test1.out', result, fmt='%.6e', delimiter=' ')
# Out:
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)
# (1, 50176)

# %%
result
# Out:
# array([[0.80784314, 0.7620915 , 0.84575163, ..., 0.60522876, 0.60784314,
#         0.61830065],
#        [0.7124183 , 0.73986928, 0.72679739, ..., 0.4248366 , 0.59215686,
#         0.59346405],
#        [0.36993464, 0.43529412, 0.40392157, ..., 0.24836601, 0.51895425,
#         0.37385621],
#        ...,
#        [0.15686275, 0.14901961, 0.14509804, ..., 0.2130719 , 0.26797386,
#         0.2875817 ],
#        [0.29542484, 0.2248366 , 0.24444444, ..., 0.03006536, 0.05098039,
#         0.09411765],
#        [0.94379085, 0.93071895, 0.96470588, ..., 0.62745098, 0.50196078,
#         0.61568627]])

# %%
from PIL import Image
realfile = Image.open('RawData/Real/0_the-collier-s-hut.jpg!Large.jpg')

# %%
realfile
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA1F0088208>

# %%
import numpy as np
# jpgfile.load()
data = np.asarray(realfile, dtype="double" )

# %%
data
# Out:
# array([[[243., 210., 165.],
#         [227., 197., 159.],
#         [243., 219., 185.],
#         ...,
#         [169., 155., 146.],
#         [166., 154., 156.],
#         [167., 154., 171.]],
#
#        [[224., 192., 153.],
#         [230., 201., 169.],
#         [228., 204., 178.],
#         ...,
#         [161., 143., 129.],
#         [160., 145., 140.],
#         [159., 143., 153.]],
#
#        [[234., 204., 170.],
#         [183., 157., 132.],
#         [173., 152., 133.],
#         ...,
#         [153., 135., 113.],
#         [164., 146., 136.],
#         [168., 149., 151.]],
#
#        ...,
#
#        [[145., 129., 132.],
#         [137., 118., 114.],
#         [201., 177., 165.],
#         ...,
#         [174., 152., 141.],
#         [153., 136., 129.],
#         [170., 158., 158.]],
#
#        [[150., 140., 148.],
#         [134., 120., 119.],
#         [143., 126., 118.],
#         ...,
#         [165., 146., 142.],
#         [162., 151., 147.],
# ...

# %%
fakefile=Image.open('RawData/Fake/0_img_3088.png')

# %%
fdata = np.asarray(fakefile, dtype="int32" )

# %%
t1=np.mean(fdata, axis=2)

# %%
t1/255
# Out:
# array([[0.96470588, 0.95      , 0.94705882, ..., 0.93235294, 0.93823529,
#         0.95      ],
#        [0.94117647, 0.92941176, 0.91176471, ..., 0.88823529, 0.9       ,
#         0.91764706],
#        [0.93529412, 0.90588235, 0.93529412, ..., 0.87058824, 0.86764706,
#         0.93529412],
#        ...,
#        [0.97941176, 0.97352941, 0.96176471, ..., 0.91176471, 0.89705882,
#         0.93235294],
#        [0.99705882, 0.97352941, 0.97647059, ..., 0.92352941, 0.94411765,
#         0.94411765],
#        [0.99411765, 0.99411765, 1.        , ..., 0.95294118, 0.94705882,
#         0.97352941]])

# %%
t2=np.mean(data, axis=2)

# %%
type(t2/255)
# Out:
# numpy.ndarray
